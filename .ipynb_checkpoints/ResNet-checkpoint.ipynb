# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision
from torchvision import datasets,transforms
import matplotlib.pyplot as plt
from torchsummary import summary

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda:0

# %% [markdown]
# # prepare data

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize([224, 224])
])

# %%
train = datasets.ImageFolder(root='../../data/imagenet-mini/train/', transform=transform)
test = datasets.ImageFolder(root='../../data/imagenet-mini/val/', transform=transform)

train_loader = torch.utils.data.DataLoader(train, batch_size=4, shuffle=True, num_workers=10)
test_loader = torch.utils.data.DataLoader(train, batch_size=4, shuffle=True, num_workers=10)

# %% [markdown]
# ## iterating data

# %%
img, label = (next(iter(train_loader)))
# Out:
# /home/hykhhijk/anaconda3/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(

# %%
plt.imshow(np.transpose(img[0], (1, 2, 0)))

# %% [markdown]
# # Define model

# %%
class Resblock(nn.Module):
    def __init__(self, ksize=3, channel_in=64, channel_out=64, init_block = False, USE_BATCH_NORM=True):
        #구현하면서 init_block는 뺄지 생각해보자
        super().__init__()
        self.shortcut = nn.Conv2d(in_channels=channel_in, out_channels=channel_out, kernel_size=1, stride=2)
        self.layers = []
        self.init_block = init_block
        if self.init_block==True:
            stride_init = 2
        else:
            stride_init = 1
            #잔차계산을 위해 모듈화시킬것
        self.layers.append(nn.Conv2d(in_channels=channel_in, out_channels=channel_out,
                            kernel_size=ksize,
                             stride=stride_init,
                             padding=ksize//2))
        self.layers.append(nn.BatchNorm2d(channel_out))
        self.layers.append(nn.ReLU(True))

        self.layers.append(nn.Conv2d(in_channels=channel_out, out_channels=channel_out,
                            kernel_size=ksize,
                             stride=1,
                             padding=ksize//2))
        self.layers.append(nn.BatchNorm2d(channel_out))
#             self.layers.append(nn.ReLU(True))  #use relu after residual sum
        self.resblock = nn.Sequential(*self.layers)
        
        
    def forward(self, x):
        if self.init_block==True:
#             result = 
            return F.relu(self.resblock(x) + self.shortcut(x))
        else:
            return F.relu(self.resblock(x))

# %%
class ResNet(nn.Module):
    def __init__(self, name="resnet", xdim=[3, 224, 224], ksize=3, cdims=[64, 128, 256, 512], layeriter=[3,4,6,3],
                hdim=1000, USE_BATCH_NORM=True):
        super().__init__()
        self.name = name
        self.xdim = xdim    #means C, W, H
        self.cdims = cdims  #Channels
        self.hdim = hdim    #Output dimension
        self.ksize = ksize
        self.USE_BATCH_NORM = USE_BATCH_NORM
        
        #Convnet
        self.layers=[]
        prev_cdim = self.xdim[0]
        self.layers.append(nn.Conv2d(in_channels=prev_cdim, out_channels=64,
                                    kernel_size=7,
                                    stride=2,
                                    padding=7//2))
        self.layers.append(nn.BatchNorm2d(64))
        self.layers.append(nn.ReLU(True))  #no maxpool and dropout
        self.layers.append(nn.MaxPool2d(2))
        prev_cdim=64
        
#         layers=[]
        for index, cdim in enumerate(self.cdims):
            iteration = layeriter[index]
            
            #이 아래부터 구현할예정
            for i in range(iteration):
                if i==0:
                    init_block=True
                    if cdims[index]==64:
                        init_block=False
                else:
                    init_block=False
                    
                    #잔차계산을 위해 모듈화시킬것
                self.layers.append(Resblock(channel_in=prev_cdim, channel_out=cdims[index],
                                           init_block=init_block))
                prev_cdim = cdims[index]
                    
        self.net = nn.Sequential(*self.layers)     
                    
#                 self.layers.append(nn.Conv2d(in_channels=prev_cdim, out_channels=cdim,
#                                     kernel_size=self.ksize,
#                                      stride=stride_init,
#                                      padding=self.ksize//2))
#                 self.layers.append(nn.BatchNorm2d(cdim))
#                 self.layers.append(nn.ReLU(True))
                
#                 self.layers.append(nn.Conv2d(in_channels=cdim, out_channels=cdim,
#                                     kernel_size=self.ksize,
#                                      stride=1,
#                                      padding=self.ksize//2))
#                 self.layers.append(nn.BatchNorm2d(cdim))
#                 self.layers.append(nn.ReLU(True))
                
                
                
                
                
                
        
        self.layers.append(nn.AdaptiveAvgPool2d((1, 1))) #넣어준 인자만큼의 space로 채널을 평균 풀링해주는듯?
        self.layers.append(nn.Flatten())
        self.layers.append(nn.Linear(prev_cdim, hdim, bias=True))
        
        self.net = nn.Sequential()
        for l_idx,layer in enumerate(self.layers):
            layer_name = "%s_%02d"%(type(layer).__name__.lower(),l_idx)
            self.net.add_module(layer_name,layer)
        self.net
        self.init_param() # initialize parameters
        
    def init_param(self):
        for m in self.modules():
            if isinstance(m,nn.Conv2d): # init conv
                nn.init.kaiming_normal_(m.weight)
                nn.init.zeros_(m.bias)
            elif isinstance(m,nn.BatchNorm2d): # init BN
                nn.init.constant_(m.weight,1)
                nn.init.constant_(m.bias,0)
            elif isinstance(m,nn.Linear): # lnit dense
                nn.init.kaiming_normal_(m.weight)
                nn.init.zeros_(m.bias)
            
            
    def forward(self, x):
        return self.net(x)
    
resnet = ResNet(name="resnet", xdim=[3, 224, 224], ksize=3, cdims=[64, 128, 256, 512], layeriter=[3,4,6,3],
        hdim=1000, USE_BATCH_NORM=True).to(device)

# %%
summary(resnet, (3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,472
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]          36,928
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,928
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#          Resblock-10           [-1, 64, 56, 56]               0
#            Conv2d-11           [-1, 64, 56, 56]          36,928
#       BatchNorm2d-12           [-1, 64, 56, 56]             128
#              ReLU-13           [-1, 64, 56, 56]               0
#            Conv2d-14           [-1, 64, 56, 56]          36,928
#       BatchNorm2d-15           [-1, 64, 56, 56]             128
#          Resblock-16           [-1, 64, 56, 56]               0
#            Conv2d-17           [-1, 64, 56, 56]          36,928
#       BatchNorm2d-18           [-1, 64, 56, 56]             128
#              ReLU-19           [-1, 64, 56, 56]               0
#            Conv2d-20           [-1, 64, 56, 56]          36,928
#       BatchNorm2d-21           [-1, 64, 56, 56]             128
#          Resblock-22           [-1, 64, 56, 56]               0
#            Conv2d-23          [-1, 128, 28, 28]          73,856
#       BatchNorm2d-24          [-1, 128, 28, 28]             256
#              ReLU-25          [-1, 128, 28, 28]               0
#            Conv2d-26          [-1, 128, 28, 28]         147,584
#       BatchNorm2d-27          [-1, 128, 28, 28]             256
#            Conv2d-28          [-1, 128, 28, 28]           8,320
#          Resblock-29          [-1, 128, 28, 28]               0
#            Conv2d-30          [-1, 128, 28, 28]         147,584
#       BatchNorm2d-31          [-1, 128, 28, 28]             256
#              ReLU-32          [-1, 128, 28, 28]               0
#            Conv2d-33          [-1, 128, 28, 28]         147,584
#       BatchNorm2d-34          [-1, 128, 28, 28]             256
#          Resblock-35          [-1, 128, 28, 28]               0
#            Conv2d-36          [-1, 128, 28, 28]         147,584
#       BatchNorm2d-37          [-1, 128, 28, 28]             256
#              ReLU-38          [-1, 128, 28, 28]               0
#            Conv2d-39          [-1, 128, 28, 28]         147,584
#       BatchNorm2d-40          [-1, 128, 28, 28]             256
#          Resblock-41          [-1, 128, 28, 28]               0
#            Conv2d-42          [-1, 128, 28, 28]         147,584
#       BatchNorm2d-43          [-1, 128, 28, 28]             256
#              ReLU-44          [-1, 128, 28, 28]               0
#            Conv2d-45          [-1, 128, 28, 28]         147,584
#       BatchNorm2d-46          [-1, 128, 28, 28]             256
#          Resblock-47          [-1, 128, 28, 28]               0
#            Conv2d-48          [-1, 256, 14, 14]         295,168
#       BatchNorm2d-49          [-1, 256, 14, 14]             512
#              ReLU-50          [-1, 256, 14, 14]               0
#            Conv2d-51          [-1, 256, 14, 14]         590,080
#       BatchNorm2d-52          [-1, 256, 14, 14]             512
#            Conv2d-53          [-1, 256, 14, 14]          33,024
#          Resblock-54          [-1, 256, 14, 14]               0
#            Conv2d-55          [-1, 256, 14, 14]         590,080
#       BatchNorm2d-56          [-1, 256, 14, 14]             512
#              ReLU-57          [-1, 256, 14, 14]               0
#            Conv2d-58          [-1, 256, 14, 14]         590,080
#       BatchNorm2d-59          [-1, 256, 14, 14]             512
#          Resblock-60          [-1, 256, 14, 14]               0
#            Conv2d-61          [-1, 256, 14, 14]         590,080
#       BatchNorm2d-62          [-1, 256, 14, 14]             512
#              ReLU-63          [-1, 256, 14, 14]               0
#            Conv2d-64          [-1, 256, 14, 14]         590,080
#       BatchNorm2d-65          [-1, 256, 14, 14]             512
#          Resblock-66          [-1, 256, 14, 14]               0
#            Conv2d-67          [-1, 256, 14, 14]         590,080
#       BatchNorm2d-68          [-1, 256, 14, 14]             512
#              ReLU-69          [-1, 256, 14, 14]               0
#            Conv2d-70          [-1, 256, 14, 14]         590,080
#       BatchNorm2d-71          [-1, 256, 14, 14]             512
#          Resblock-72          [-1, 256, 14, 14]               0
#            Conv2d-73          [-1, 256, 14, 14]         590,080
#       BatchNorm2d-74          [-1, 256, 14, 14]             512
#              ReLU-75          [-1, 256, 14, 14]               0
#            Conv2d-76          [-1, 256, 14, 14]         590,080
#       BatchNorm2d-77          [-1, 256, 14, 14]             512
#          Resblock-78          [-1, 256, 14, 14]               0
#            Conv2d-79          [-1, 256, 14, 14]         590,080
#       BatchNorm2d-80          [-1, 256, 14, 14]             512
#              ReLU-81          [-1, 256, 14, 14]               0
#            Conv2d-82          [-1, 256, 14, 14]         590,080
#       BatchNorm2d-83          [-1, 256, 14, 14]             512
#          Resblock-84          [-1, 256, 14, 14]               0
#            Conv2d-85            [-1, 512, 7, 7]       1,180,160
#       BatchNorm2d-86            [-1, 512, 7, 7]           1,024
#              ReLU-87            [-1, 512, 7, 7]               0
#            Conv2d-88            [-1, 512, 7, 7]       2,359,808
#       BatchNorm2d-89            [-1, 512, 7, 7]           1,024
#            Conv2d-90            [-1, 512, 7, 7]         131,584
#          Resblock-91            [-1, 512, 7, 7]               0
#            Conv2d-92            [-1, 512, 7, 7]       2,359,808
#       BatchNorm2d-93            [-1, 512, 7, 7]           1,024
#              ReLU-94            [-1, 512, 7, 7]               0
#            Conv2d-95            [-1, 512, 7, 7]       2,359,808
#       BatchNorm2d-96            [-1, 512, 7, 7]           1,024
#          Resblock-97            [-1, 512, 7, 7]               0
#            Conv2d-98            [-1, 512, 7, 7]       2,359,808
#       BatchNorm2d-99            [-1, 512, 7, 7]           1,024
#             ReLU-100            [-1, 512, 7, 7]               0
#           Conv2d-101            [-1, 512, 7, 7]       2,359,808
#      BatchNorm2d-102            [-1, 512, 7, 7]           1,024
#         Resblock-103            [-1, 512, 7, 7]               0
# AdaptiveAvgPool2d-104            [-1, 512, 1, 1]               0
#          Flatten-105                  [-1, 512]               0
#           Linear-106                 [-1, 1000]         513,000
# ================================================================
# Total params: 21,804,392
# Trainable params: 21,804,392
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 84.43
# Params size (MB): 83.18
# Estimated Total Size (MB): 168.18
# ----------------------------------------------------------------

# %% [markdown]
# ## Check Parameters

# %%
np.set_printoptions(precision=3)
n_param = 0
for p_idx,(param_name,param) in enumerate(resnet.named_parameters()):
    if param.requires_grad:
        param_numpy = param.detach().cpu().numpy() # to numpy array 
        n_param += len(param_numpy.reshape(-1))
        print ("[%d] name:[%s] shape:[%s]."%(p_idx,param_name,param_numpy.shape))
        print ("    val:%s"%(param_numpy.reshape(-1)[:5]))   #1차원으로 만든다음 앞의 5개만 가져오는 head()와 비슷한 역활
print ("Total number of parameters:[%s]."%(format(n_param,',d')))
# Out:
# [0] name:[net.conv2d_00.weight] shape:[(64, 3, 7, 7)].
#     val:[ 0.144 -0.076  0.142 -0.072  0.012]
# [1] name:[net.conv2d_00.bias] shape:[(64,)].
#     val:[0. 0. 0. 0. 0.]
# [2] name:[net.batchnorm2d_01.weight] shape:[(64,)].
#     val:[1. 1. 1. 1. 1.]
# [3] name:[net.batchnorm2d_01.bias] shape:[(64,)].
#     val:[0. 0. 0. 0. 0.]
# [4] name:[net.resblock_04.shortcut.weight] shape:[(64, 64, 1, 1)].
#     val:[-0.275 -0.038  0.05  -0.022 -0.131]
# [5] name:[net.resblock_04.shortcut.bias] shape:[(64,)].
#     val:[0. 0. 0. 0. 0.]
# [6] name:[net.resblock_04.resblock.0.weight] shape:[(64, 64, 3, 3)].
#     val:[-0.001  0.072  0.045  0.154 -0.046]
# [7] name:[net.resblock_04.resblock.0.bias] shape:[(64,)].
#     val:[0. 0. 0. 0. 0.]
# [8] name:[net.resblock_04.resblock.1.weight] shape:[(64,)].
#     val:[1. 1. 1. 1. 1.]
# [9] name:[net.resblock_04.resblock.1.bias] shape:[(64,)].
#     val:[0. 0. 0. 0. 0.]
# [10] name:[net.resblock_04.resblock.3.weight] shape:[(64, 64, 3, 3)].
#     val:[ 0.06  -0.043  0.038  0.08  -0.021]
# [11] name:[net.resblock_04.resblock.3.bias] shape:[(64,)].
#     val:[0. 0. 0. 0. 0.]
# [12] name:[net.resblock_04.resblock.4.weight] shape:[(64,)].
#     val:[1. 1. 1. 1. 1.]
# [13] name:[net.resblock_04.resblock.4.bias] shape:[(64,)].
#     val:[0. 0. 0. 0. 0.]
# [14] name:[net.resblock_05.shortcut.weight] shape:[(64, 64, 1, 1)].
#     val:[-0.404 -0.028 -0.007  0.174 -0.119]
# [15] name:[net.resblock_05.shortcut.bias] shape:[(64,)].
#     val:[0. 0. 0. 0. 0.]
# [16] name:[net.resblock_05.resblock.0.weight] shape:[(64, 64, 3, 3)].
#     val:[ 0.14  -0.056 -0.038 -0.111 -0.031]
# [17] name:[net.resblock_05.resblock.0.bias] shape:[(64,)].
#     val:[0. 0. 0. 0. 0.]
# [18] name:[net.resblock_05.resblock.1.weight] shape:[(64,)].
#     val:[1. 1. 1. 1. 1.]
# [19] name:[net.resblock_05.resblock.1.bias] shape:[(64,)].
#     val:[0. 0. 0. 0. 0.]
# [20] name:[net.resblock_05.resblock.3.weight] shape:[(64, 64, 3, 3)].
#     val:[-0.031  0.086  0.05   0.022 -0.02 ]
# [21] name:[net.resblock_05.resblock.3.bias] shape:[(64,)].
#     val:[0. 0. 0. 0. 0.]
# [22] name:[net.resblock_05.resblock.4.weight] shape:[(64,)].
#     val:[1. 1. 1. 1. 1.]
# [23] name:[net.resblock_05.resblock.4.bias] shape:[(64,)].
#     val:[0. 0. 0. 0. 0.]
# [24] name:[net.resblock_06.shortcut.weight] shape:[(64, 64, 1, 1)].
#     val:[ 0.223 -0.159  0.299 -0.255  0.062]
# [25] name:[net.resblock_06.shortcut.bias] shape:[(64,)].
#     val:[0. 0. 0. 0. 0.]
# [26] name:[net.resblock_06.resblock.0.weight] shape:[(64, 64, 3, 3)].
#     val:[ 0.11  -0.077 -0.098 -0.003  0.045]
# [27] name:[net.resblock_06.resblock.0.bias] shape:[(64,)].
#     val:[0. 0. 0. 0. 0.]
# [28] name:[net.resblock_06.resblock.1.weight] shape:[(64,)].
#     val:[1. 1. 1. 1. 1.]
# [29] name:[net.resblock_06.resblock.1.bias] shape:[(64,)].
#     val:[0. 0. 0. 0. 0.]
# [30] name:[net.resblock_06.resblock.3.weight] shape:[(64, 64, 3, 3)].
#     val:[ 0.001  0.062 -0.043  0.039 -0.03 ]
# [31] name:[net.resblock_06.resblock.3.bias] shape:[(64,)].
#     val:[0. 0. 0. 0. 0.]
# [32] name:[net.resblock_06.resblock.4.weight] shape:[(64,)].
#     val:[1. 1. 1. 1. 1.]
# [33] name:[net.resblock_06.resblock.4.bias] shape:[(64,)].
#     val:[0. 0. 0. 0. 0.]
# [34] name:[net.resblock_07.shortcut.weight] shape:[(128, 64, 1, 1)].
#     val:[ 0.021  0.046 -0.37   0.121 -0.012]
# [35] name:[net.resblock_07.shortcut.bias] shape:[(128,)].
#     val:[0. 0. 0. 0. 0.]
# [36] name:[net.resblock_07.resblock.0.weight] shape:[(128, 64, 3, 3)].
#     val:[-0.052 -0.061 -0.032 -0.003  0.054]
# [37] name:[net.resblock_07.resblock.0.bias] shape:[(128,)].
#     val:[0. 0. 0. 0. 0.]
# [38] name:[net.resblock_07.resblock.1.weight] shape:[(128,)].
#     val:[1. 1. 1. 1. 1.]
# [39] name:[net.resblock_07.resblock.1.bias] shape:[(128,)].
#     val:[0. 0. 0. 0. 0.]
# [40] name:[net.resblock_07.resblock.3.weight] shape:[(128, 128, 3, 3)].
#     val:[ 0.033 -0.009  0.027  0.006  0.036]
# [41] name:[net.resblock_07.resblock.3.bias] shape:[(128,)].
#     val:[0. 0. 0. 0. 0.]
# [42] name:[net.resblock_07.resblock.4.weight] shape:[(128,)].
#     val:[1. 1. 1. 1. 1.]
# [43] name:[net.resblock_07.resblock.4.bias] shape:[(128,)].
#     val:[0. 0. 0. 0. 0.]
# [44] name:[net.resblock_08.shortcut.weight] shape:[(128, 128, 1, 1)].
#     val:[-0.163  0.195  0.207 -0.124 -0.062]
# [45] name:[net.resblock_08.shortcut.bias] shape:[(128,)].
#     val:[0. 0. 0. 0. 0.]
# [46] name:[net.resblock_08.resblock.0.weight] shape:[(128, 128, 3, 3)].
#     val:[ 0.004 -0.037  0.043  0.065 -0.009]
# [47] name:[net.resblock_08.resblock.0.bias] shape:[(128,)].
#     val:[0. 0. 0. 0. 0.]
# [48] name:[net.resblock_08.resblock.1.weight] shape:[(128,)].
#     val:[1. 1. 1. 1. 1.]
# [49] name:[net.resblock_08.resblock.1.bias] shape:[(128,)].
#     val:[0. 0. 0. 0. 0.]
# [50] name:[net.resblock_08.resblock.3.weight] shape:[(128, 128, 3, 3)].
#     val:[ 0.018 -0.048 -0.059 -0.019  0.006]
# [51] name:[net.resblock_08.resblock.3.bias] shape:[(128,)].
#     val:[0. 0. 0. 0. 0.]
# [52] name:[net.resblock_08.resblock.4.weight] shape:[(128,)].
#     val:[1. 1. 1. 1. 1.]
# [53] name:[net.resblock_08.resblock.4.bias] shape:[(128,)].
#     val:[0. 0. 0. 0. 0.]
# [54] name:[net.resblock_09.shortcut.weight] shape:[(128, 128, 1, 1)].
#     val:[ 0.218 -0.07  -0.132  0.044 -0.072]
# [55] name:[net.resblock_09.shortcut.bias] shape:[(128,)].
#     val:[0. 0. 0. 0. 0.]
# [56] name:[net.resblock_09.resblock.0.weight] shape:[(128, 128, 3, 3)].
#     val:[ 0.008 -0.033 -0.018  0.079 -0.004]
# [57] name:[net.resblock_09.resblock.0.bias] shape:[(128,)].
#     val:[0. 0. 0. 0. 0.]
# [58] name:[net.resblock_09.resblock.1.weight] shape:[(128,)].
#     val:[1. 1. 1. 1. 1.]
# [59] name:[net.resblock_09.resblock.1.bias] shape:[(128,)].
#     val:[0. 0. 0. 0. 0.]
# [60] name:[net.resblock_09.resblock.3.weight] shape:[(128, 128, 3, 3)].
#     val:[ 0.014  0.01  -0.059 -0.024 -0.061]
# [61] name:[net.resblock_09.resblock.3.bias] shape:[(128,)].
#     val:[0. 0. 0. 0. 0.]
# [62] name:[net.resblock_09.resblock.4.weight] shape:[(128,)].
#     val:[1. 1. 1. 1. 1.]
# [63] name:[net.resblock_09.resblock.4.bias] shape:[(128,)].
#     val:[0. 0. 0. 0. 0.]
# [64] name:[net.resblock_10.shortcut.weight] shape:[(128, 128, 1, 1)].
#     val:[ 0.15   0.162 -0.053 -0.131  0.105]
# [65] name:[net.resblock_10.shortcut.bias] shape:[(128,)].
#     val:[0. 0. 0. 0. 0.]
# [66] name:[net.resblock_10.resblock.0.weight] shape:[(128, 128, 3, 3)].
#     val:[ 0.002 -0.005  0.046 -0.027  0.007]
# [67] name:[net.resblock_10.resblock.0.bias] shape:[(128,)].
#     val:[0. 0. 0. 0. 0.]
# [68] name:[net.resblock_10.resblock.1.weight] shape:[(128,)].
#     val:[1. 1. 1. 1. 1.]
# [69] name:[net.resblock_10.resblock.1.bias] shape:[(128,)].
#     val:[0. 0. 0. 0. 0.]
# [70] name:[net.resblock_10.resblock.3.weight] shape:[(128, 128, 3, 3)].
#     val:[ 0.04  -0.019  0.019 -0.023  0.026]
# [71] name:[net.resblock_10.resblock.3.bias] shape:[(128,)].
#     val:[0. 0. 0. 0. 0.]
# [72] name:[net.resblock_10.resblock.4.weight] shape:[(128,)].
#     val:[1. 1. 1. 1. 1.]
# [73] name:[net.resblock_10.resblock.4.bias] shape:[(128,)].
#     val:[0. 0. 0. 0. 0.]
# [74] name:[net.resblock_11.shortcut.weight] shape:[(256, 128, 1, 1)].
#     val:[-0.029  0.153 -0.082  0.213  0.114]
# [75] name:[net.resblock_11.shortcut.bias] shape:[(256,)].
#     val:[0. 0. 0. 0. 0.]
# [76] name:[net.resblock_11.resblock.0.weight] shape:[(256, 128, 3, 3)].
#     val:[ 0.018 -0.048 -0.11   0.038  0.007]
# [77] name:[net.resblock_11.resblock.0.bias] shape:[(256,)].
#     val:[0. 0. 0. 0. 0.]
# [78] name:[net.resblock_11.resblock.1.weight] shape:[(256,)].
#     val:[1. 1. 1. 1. 1.]
# [79] name:[net.resblock_11.resblock.1.bias] shape:[(256,)].
#     val:[0. 0. 0. 0. 0.]
# [80] name:[net.resblock_11.resblock.3.weight] shape:[(256, 256, 3, 3)].
#     val:[ 0.007 -0.022  0.032  0.009  0.026]
# [81] name:[net.resblock_11.resblock.3.bias] shape:[(256,)].
#     val:[0. 0. 0. 0. 0.]
# [82] name:[net.resblock_11.resblock.4.weight] shape:[(256,)].
#     val:[1. 1. 1. 1. 1.]
# [83] name:[net.resblock_11.resblock.4.bias] shape:[(256,)].
#     val:[0. 0. 0. 0. 0.]
# [84] name:[net.resblock_12.shortcut.weight] shape:[(256, 256, 1, 1)].
#     val:[-0.1   -0.171 -0.01   0.044  0.042]
# [85] name:[net.resblock_12.shortcut.bias] shape:[(256,)].
#     val:[0. 0. 0. 0. 0.]
# [86] name:[net.resblock_12.resblock.0.weight] shape:[(256, 256, 3, 3)].
#     val:[-0.027 -0.023 -0.007 -0.009  0.019]
# [87] name:[net.resblock_12.resblock.0.bias] shape:[(256,)].
#     val:[0. 0. 0. 0. 0.]
# [88] name:[net.resblock_12.resblock.1.weight] shape:[(256,)].
#     val:[1. 1. 1. 1. 1.]
# [89] name:[net.resblock_12.resblock.1.bias] shape:[(256,)].
#     val:[0. 0. 0. 0. 0.]
# [90] name:[net.resblock_12.resblock.3.weight] shape:[(256, 256, 3, 3)].
#     val:[-0.031 -0.005 -0.019 -0.001 -0.016]
# [91] name:[net.resblock_12.resblock.3.bias] shape:[(256,)].
#     val:[0. 0. 0. 0. 0.]
# [92] name:[net.resblock_12.resblock.4.weight] shape:[(256,)].
#     val:[1. 1. 1. 1. 1.]
# [93] name:[net.resblock_12.resblock.4.bias] shape:[(256,)].
#     val:[0. 0. 0. 0. 0.]
# [94] name:[net.resblock_13.shortcut.weight] shape:[(256, 256, 1, 1)].
#     val:[ 0.086 -0.054  0.013 -0.069  0.007]
# [95] name:[net.resblock_13.shortcut.bias] shape:[(256,)].
#     val:[0. 0. 0. 0. 0.]
# [96] name:[net.resblock_13.resblock.0.weight] shape:[(256, 256, 3, 3)].
#     val:[ 0.033  0.002  0.002  0.013 -0.019]
# [97] name:[net.resblock_13.resblock.0.bias] shape:[(256,)].
#     val:[0. 0. 0. 0. 0.]
# [98] name:[net.resblock_13.resblock.1.weight] shape:[(256,)].
#     val:[1. 1. 1. 1. 1.]
# [99] name:[net.resblock_13.resblock.1.bias] shape:[(256,)].
#     val:[0. 0. 0. 0. 0.]
# [100] name:[net.resblock_13.resblock.3.weight] shape:[(256, 256, 3, 3)].
#     val:[ 0.019 -0.001 -0.006  0.016 -0.013]
# [101] name:[net.resblock_13.resblock.3.bias] shape:[(256,)].
#     val:[0. 0. 0. 0. 0.]
# [102] name:[net.resblock_13.resblock.4.weight] shape:[(256,)].
#     val:[1. 1. 1. 1. 1.]
# [103] name:[net.resblock_13.resblock.4.bias] shape:[(256,)].
#     val:[0. 0. 0. 0. 0.]
# [104] name:[net.resblock_14.shortcut.weight] shape:[(256, 256, 1, 1)].
#     val:[ 0.002  0.035  0.084 -0.128 -0.032]
# [105] name:[net.resblock_14.shortcut.bias] shape:[(256,)].
#     val:[0. 0. 0. 0. 0.]
# [106] name:[net.resblock_14.resblock.0.weight] shape:[(256, 256, 3, 3)].
#     val:[ 0.067  0.005  0.021 -0.005  0.006]
# [107] name:[net.resblock_14.resblock.0.bias] shape:[(256,)].
#     val:[0. 0. 0. 0. 0.]
# [108] name:[net.resblock_14.resblock.1.weight] shape:[(256,)].
#     val:[1. 1. 1. 1. 1.]
# [109] name:[net.resblock_14.resblock.1.bias] shape:[(256,)].
#     val:[0. 0. 0. 0. 0.]
# [110] name:[net.resblock_14.resblock.3.weight] shape:[(256, 256, 3, 3)].
#     val:[ 0.02  -0.    -0.042 -0.026 -0.004]
# [111] name:[net.resblock_14.resblock.3.bias] shape:[(256,)].
#     val:[0. 0. 0. 0. 0.]
# [112] name:[net.resblock_14.resblock.4.weight] shape:[(256,)].
#     val:[1. 1. 1. 1. 1.]
# [113] name:[net.resblock_14.resblock.4.bias] shape:[(256,)].
#     val:[0. 0. 0. 0. 0.]
# [114] name:[net.resblock_15.shortcut.weight] shape:[(256, 256, 1, 1)].
#     val:[-0.026  0.033  0.163 -0.113  0.008]
# [115] name:[net.resblock_15.shortcut.bias] shape:[(256,)].
#     val:[0. 0. 0. 0. 0.]
# [116] name:[net.resblock_15.resblock.0.weight] shape:[(256, 256, 3, 3)].
#     val:[ 0.042 -0.034  0.034 -0.03  -0.016]
# [117] name:[net.resblock_15.resblock.0.bias] shape:[(256,)].
#     val:[0. 0. 0. 0. 0.]
# [118] name:[net.resblock_15.resblock.1.weight] shape:[(256,)].
#     val:[1. 1. 1. 1. 1.]
# [119] name:[net.resblock_15.resblock.1.bias] shape:[(256,)].
#     val:[0. 0. 0. 0. 0.]
# [120] name:[net.resblock_15.resblock.3.weight] shape:[(256, 256, 3, 3)].
#     val:[ 0.009  0.036 -0.049  0.006  0.03 ]
# [121] name:[net.resblock_15.resblock.3.bias] shape:[(256,)].
#     val:[0. 0. 0. 0. 0.]
# [122] name:[net.resblock_15.resblock.4.weight] shape:[(256,)].
#     val:[1. 1. 1. 1. 1.]
# [123] name:[net.resblock_15.resblock.4.bias] shape:[(256,)].
#     val:[0. 0. 0. 0. 0.]
# [124] name:[net.resblock_16.shortcut.weight] shape:[(256, 256, 1, 1)].
#     val:[ 0.015  0.013 -0.272  0.038 -0.028]
# [125] name:[net.resblock_16.shortcut.bias] shape:[(256,)].
#     val:[0. 0. 0. 0. 0.]
# [126] name:[net.resblock_16.resblock.0.weight] shape:[(256, 256, 3, 3)].
#     val:[-0.032 -0.011  0.071 -0.012  0.023]
# [127] name:[net.resblock_16.resblock.0.bias] shape:[(256,)].
#     val:[0. 0. 0. 0. 0.]
# [128] name:[net.resblock_16.resblock.1.weight] shape:[(256,)].
#     val:[1. 1. 1. 1. 1.]
# [129] name:[net.resblock_16.resblock.1.bias] shape:[(256,)].
#     val:[0. 0. 0. 0. 0.]
# [130] name:[net.resblock_16.resblock.3.weight] shape:[(256, 256, 3, 3)].
#     val:[ 1.216e-02 -3.585e-02 -4.845e-02  4.969e-02  6.156e-05]
# [131] name:[net.resblock_16.resblock.3.bias] shape:[(256,)].
#     val:[0. 0. 0. 0. 0.]
# [132] name:[net.resblock_16.resblock.4.weight] shape:[(256,)].
#     val:[1. 1. 1. 1. 1.]
# [133] name:[net.resblock_16.resblock.4.bias] shape:[(256,)].
#     val:[0. 0. 0. 0. 0.]
# [134] name:[net.resblock_17.shortcut.weight] shape:[(512, 256, 1, 1)].
#     val:[-0.078 -0.037  0.092 -0.034  0.037]
# [135] name:[net.resblock_17.shortcut.bias] shape:[(512,)].
#     val:[0. 0. 0. 0. 0.]
# [136] name:[net.resblock_17.resblock.0.weight] shape:[(512, 256, 3, 3)].
#     val:[-0.032  0.004  0.03  -0.044  0.009]
# [137] name:[net.resblock_17.resblock.0.bias] shape:[(512,)].
#     val:[0. 0. 0. 0. 0.]
# [138] name:[net.resblock_17.resblock.1.weight] shape:[(512,)].
#     val:[1. 1. 1. 1. 1.]
# [139] name:[net.resblock_17.resblock.1.bias] shape:[(512,)].
#     val:[0. 0. 0. 0. 0.]
# [140] name:[net.resblock_17.resblock.3.weight] shape:[(512, 512, 3, 3)].
#     val:[ 0.007  0.026  0.049 -0.025 -0.005]
# [141] name:[net.resblock_17.resblock.3.bias] shape:[(512,)].
#     val:[0. 0. 0. 0. 0.]
# [142] name:[net.resblock_17.resblock.4.weight] shape:[(512,)].
#     val:[1. 1. 1. 1. 1.]
# [143] name:[net.resblock_17.resblock.4.bias] shape:[(512,)].
#     val:[0. 0. 0. 0. 0.]
# [144] name:[net.resblock_18.shortcut.weight] shape:[(512, 512, 1, 1)].
#     val:[ 0.003  0.014 -0.015 -0.055  0.051]
# [145] name:[net.resblock_18.shortcut.bias] shape:[(512,)].
#     val:[0. 0. 0. 0. 0.]
# [146] name:[net.resblock_18.resblock.0.weight] shape:[(512, 512, 3, 3)].
#     val:[ 0.008  0.005  0.047  0.02  -0.028]
# [147] name:[net.resblock_18.resblock.0.bias] shape:[(512,)].
#     val:[0. 0. 0. 0. 0.]
# [148] name:[net.resblock_18.resblock.1.weight] shape:[(512,)].
#     val:[1. 1. 1. 1. 1.]
# [149] name:[net.resblock_18.resblock.1.bias] shape:[(512,)].
#     val:[0. 0. 0. 0. 0.]
# [150] name:[net.resblock_18.resblock.3.weight] shape:[(512, 512, 3, 3)].
#     val:[ 0.011 -0.013 -0.02   0.025  0.016]
# [151] name:[net.resblock_18.resblock.3.bias] shape:[(512,)].
#     val:[0. 0. 0. 0. 0.]
# [152] name:[net.resblock_18.resblock.4.weight] shape:[(512,)].
#     val:[1. 1. 1. 1. 1.]
# [153] name:[net.resblock_18.resblock.4.bias] shape:[(512,)].
#     val:[0. 0. 0. 0. 0.]
# [154] name:[net.resblock_19.shortcut.weight] shape:[(512, 512, 1, 1)].
#     val:[ 0.043 -0.104 -0.048  0.046  0.076]
# [155] name:[net.resblock_19.shortcut.bias] shape:[(512,)].
#     val:[0. 0. 0. 0. 0.]
# [156] name:[net.resblock_19.resblock.0.weight] shape:[(512, 512, 3, 3)].
#     val:[ 0.012  0.026  0.008  0.004 -0.004]
# [157] name:[net.resblock_19.resblock.0.bias] shape:[(512,)].
#     val:[0. 0. 0. 0. 0.]
# [158] name:[net.resblock_19.resblock.1.weight] shape:[(512,)].
#     val:[1. 1. 1. 1. 1.]
# [159] name:[net.resblock_19.resblock.1.bias] shape:[(512,)].
#     val:[0. 0. 0. 0. 0.]
# [160] name:[net.resblock_19.resblock.3.weight] shape:[(512, 512, 3, 3)].
#     val:[ 0.035  0.015 -0.006 -0.008  0.002]
# [161] name:[net.resblock_19.resblock.3.bias] shape:[(512,)].
#     val:[0. 0. 0. 0. 0.]
# [162] name:[net.resblock_19.resblock.4.weight] shape:[(512,)].
#     val:[1. 1. 1. 1. 1.]
# [163] name:[net.resblock_19.resblock.4.bias] shape:[(512,)].
#     val:[0. 0. 0. 0. 0.]
# [164] name:[net.linear_22.weight] shape:[(1000, 512)].
#     val:[ 0.034  0.036  0.03   0.058 -0.048]
# [165] name:[net.linear_22.bias] shape:[(1000,)].
#     val:[0. 0. 0. 0. 0.]
# Total number of parameters:[22,720,680].

# %% [markdown]
# ## Simple Forward Path of the CNN Model

# %%
np.set_printoptions(precision=3)
torch.set_printoptions(precision=3)
x_numpy = np.random.rand(2,3,224, 224)
x_torch = torch.from_numpy(x_numpy).float().to(device)
y_torch = resnet.forward(x_torch) # forward path
y_numpy = y_torch.detach().cpu().numpy() # torch tensor to numpy array
print ("x_torch:\n",x_torch)
print ("y_torch:\n",y_torch)
print ("\nx_numpy %s:\n"%(x_numpy.shape,),x_numpy)
print ("y_numpy %s:\n"%(y_numpy.shape,),y_numpy)
# Out:
# x_torch:
#  tensor([[[[0.836, 0.971, 0.164,  ..., 0.880, 0.437, 0.499],
#           [0.992, 0.927, 0.715,  ..., 0.456, 0.054, 0.539],
#           [0.828, 0.847, 0.587,  ..., 0.797, 0.955, 0.060],
#           ...,
#           [0.784, 0.600, 0.424,  ..., 0.670, 0.944, 0.365],
#           [0.372, 0.739, 0.313,  ..., 0.729, 0.174, 0.340],
#           [0.255, 0.635, 0.977,  ..., 0.239, 0.185, 0.941]],
#
#          [[0.652, 0.723, 0.361,  ..., 0.937, 0.805, 0.279],
#           [0.902, 0.517, 0.754,  ..., 0.002, 0.154, 0.299],
#           [0.579, 0.137, 0.286,  ..., 0.562, 0.605, 0.687],
#           ...,
#           [0.386, 0.704, 0.581,  ..., 0.627, 0.920, 0.617],
#           [0.204, 0.743, 0.618,  ..., 0.366, 0.078, 0.521],
#           [0.975, 0.981, 0.411,  ..., 0.149, 0.426, 0.143]],
#
#          [[0.656, 0.531, 0.225,  ..., 0.932, 0.405, 0.385],
#           [0.941, 0.747, 0.852,  ..., 0.330, 0.456, 0.704],
#           [0.867, 0.225, 0.104,  ..., 0.270, 0.748, 0.606],
#           ...,
#           [0.263, 0.786, 0.956,  ..., 0.917, 0.870, 0.149],
#           [0.740, 0.334, 0.641,  ..., 0.240, 0.461, 0.360],
#           [0.624, 0.084, 0.253,  ..., 0.549, 0.309, 0.843]]],
#
#
#         [[[0.812, 0.131, 0.613,  ..., 0.666, 0.520, 0.363],
#           [0.603, 0.490, 0.651,  ..., 0.280, 0.180, 0.652],
#           [0.757, 0.412, 0.766,  ..., 0.064, 0.327, 0.792],
#           ...,
#           [0.600, 0.504, 0.076,  ..., 0.532, 0.448, 0.557],
#           [0.620, 0.370, 0.944,  ..., 0.844, 0.129, 0.884],
#           [0.801, 0.458, 0.093,  ..., 0.932, 0.522, 0.653]],
#
#          [[0.150, 0.651, 0.432,  ..., 0.482, 0.019, 0.169],
#           [0.375, 0.929, 0.156,  ..., 0.408, 0.475, 0.116],
#           [0.582, 0.813, 0.199,  ..., 0.076, 0.624, 0.780],
#           ...,
#           [0.981, 0.012, 0.374,  ..., 0.887, 0.861, 0.010],
#           [0.596, 0.704, 0.632,  ..., 0.091, 0.658, 0.217],
#           [0.388, 0.087, 0.427,  ..., 0.911, 0.530, 0.806]],
#
#          [[0.989, 0.873, 0.247,  ..., 0.367, 0.344, 0.109],
#           [0.578, 0.462, 0.012,  ..., 0.096, 0.609, 0.011],
#           [0.608, 0.130, 0.059,  ..., 0.386, 0.099, 0.837],
#           ...,
#           [0.973, 0.211, 0.895,  ..., 0.520, 0.926, 0.284],
#           [0.405, 0.622, 0.683,  ..., 0.992, 0.492, 0.699],
#           [0.934, 0.391, 0.707,  ..., 0.288, 0.441, 0.581]]]], device='cuda:0')
# y_torch:
#  tensor([[-0.379,  0.335, -0.241,  ..., -0.011,  0.195, -0.436],
#         [-0.508,  0.474, -0.006,  ..., -0.094,  0.176, -0.652]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
#
# x_numpy (2, 3, 224, 224):
#  [[[[0.836 0.971 0.164 ... 0.88  0.437 0.499]
#    [0.992 0.927 0.715 ... 0.456 0.054 0.539]
#    [0.828 0.847 0.587 ... 0.797 0.955 0.06 ]
#    ...
#    [0.784 0.6   0.424 ... 0.67  0.944 0.365]
#    [0.372 0.739 0.313 ... 0.729 0.174 0.34 ]
#    [0.255 0.635 0.977 ... 0.239 0.185 0.941]]
#
#   [[0.652 0.723 0.361 ... 0.937 0.805 0.279]
#    [0.902 0.517 0.754 ... 0.002 0.154 0.299]
#    [0.579 0.137 0.286 ... 0.562 0.605 0.687]
#    ...
#    [0.386 0.704 0.581 ... 0.627 0.92  0.617]
#    [0.204 0.743 0.618 ... 0.366 0.078 0.521]
#    [0.975 0.981 0.411 ... 0.149 0.426 0.143]]
#
#   [[0.656 0.531 0.225 ... 0.932 0.405 0.385]
#    [0.941 0.747 0.852 ... 0.33  0.456 0.704]
#    [0.867 0.225 0.104 ... 0.27  0.748 0.606]
#    ...
#    [0.263 0.786 0.956 ... 0.917 0.87  0.149]
#    [0.74  0.334 0.641 ... 0.24  0.461 0.36 ]
#    [0.624 0.084 0.253 ... 0.549 0.309 0.843]]]
#
#
#  [[[0.812 0.131 0.613 ... 0.666 0.52  0.363]
#    [0.603 0.49  0.651 ... 0.28  0.18  0.652]
#    [0.757 0.412 0.766 ... 0.064 0.327 0.792]
#    ...
#    [0.6   0.504 0.076 ... 0.532 0.448 0.557]
#    [0.62  0.37  0.944 ... 0.844 0.129 0.884]
#    [0.801 0.458 0.093 ... 0.932 0.522 0.653]]
#
#   [[0.15  0.651 0.432 ... 0.482 0.019 0.169]
#    [0.375 0.929 0.156 ... 0.408 0.475 0.116]
#    [0.582 0.813 0.199 ... 0.076 0.624 0.78 ]
#    ...
#    [0.981 0.012 0.374 ... 0.887 0.861 0.01 ]
#    [0.596 0.704 0.632 ... 0.091 0.658 0.217]
#    [0.388 0.087 0.427 ... 0.911 0.53  0.806]]
#
#   [[0.989 0.873 0.247 ... 0.367 0.344 0.109]
#    [0.578 0.462 0.012 ... 0.096 0.609 0.011]
#    [0.608 0.13  0.059 ... 0.386 0.099 0.837]
#    ...
#    [0.973 0.211 0.895 ... 0.52  0.926 0.284]
#    [0.405 0.622 0.683 ... 0.992 0.492 0.699]
#    [0.934 0.391 0.707 ... 0.288 0.441 0.581]]]]
# y_numpy (2, 1000):
#  [[-0.379  0.335 -0.241 ... -0.011  0.195 -0.436]
#  [-0.508  0.474 -0.006 ... -0.094  0.176 -0.652]]

# %%
print(x_torch.shape, y_torch.shape)
# Out:
# torch.Size([2, 3, 224, 224]) torch.Size([2, 1000])

# %% [markdown]
# ## Define optimizer

# %%
loss = nn.CrossEntropyLoss()
optm = optim.Adam(resnet.parameters(), lr=0.0001)

# %% [markdown]
# # Train

# %%
print ("Start training.")
resnet.init_param() # initialize parameters
resnet.train() # to train mode 
EPOCHS,print_every = 10,1
for epoch in range(EPOCHS):
    loss_val_sum = 0
    for batch_in,batch_out in train_loader:
        # Forward path
        y_pred = resnet.forward(batch_in.view(-1,3,224,224).to(device))
        loss_out = loss(y_pred,batch_out.to(device))
        # Update
        optm.zero_grad()
        loss_out.backward()
        optm.step()
        loss_val_sum += loss_out
        
        # FILL IN HERE      # reset gradient 
        # FILL IN HERE      # backpropagate
        # FILL IN HERE      # optimizer update
        loss_val_sum += loss_out
    loss_val_avg = loss_val_sum/len(train_loader)
    # Print
    if ((epoch%print_every)==0) or (epoch==(EPOCHS-1)):
        print(loss_val_avg)
#         train_accr = func_eval(resnet,train_loader,device)
#         test_accr = func_eval(resnet,train_loader,device)
#         print ("epoch:[%d] loss:[%.3f] train_accr:[%.3f] test_accr:[%.3f]."%
#                (epoch,loss_val_avg,train_accr,test_accr))
print ("Done")
# Out:
# Start training.
# /home/hykhhijk/anaconda3/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/hykhhijk/anaconda3/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/hykhhijk/anaconda3/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/hykhhijk/anaconda3/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/hykhhijk/anaconda3/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/hykhhijk/anaconda3/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/hykhhijk/anaconda3/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/hykhhijk/anaconda3/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/hykhhijk/anaconda3/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/hykhhijk/anaconda3/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# tensor(13.867, device='cuda:0', grad_fn=<DivBackward0>)
# /home/hykhhijk/anaconda3/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/hykhhijk/anaconda3/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/hykhhijk/anaconda3/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/hykhhijk/anaconda3/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/hykhhijk/anaconda3/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/hykhhijk/anaconda3/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/hykhhijk/anaconda3/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/hykhhijk/anaconda3/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/hykhhijk/anaconda3/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/hykhhijk/anaconda3/lib/python3.9/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f95b3c00310>
# Traceback (most recent call last):
#   File "/home/hykhhijk/anaconda3/lib/python3.9/site-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/home/hykhhijk/anaconda3/lib/python3.9/site-packages/torch/utils/data/dataloader.py", line 1443, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/home/hykhhijk/anaconda3/lib/python3.9/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/home/hykhhijk/anaconda3/lib/python3.9/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/home/hykhhijk/anaconda3/lib/python3.9/multiprocessing/connection.py", line 936, in wait
#     ready = selector.select(timeout)
#   File "/home/hykhhijk/anaconda3/lib/python3.9/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/home/hykhhijk/anaconda3/lib/python3.9/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 1226) exited unexpectedly with exit code 1. Details are lost due to multiprocessing. Rerunning with num_workers=0 may give better error trace.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [34], line 7
#       5 for epoch in range(EPOCHS):
#       6     loss_val_sum = 0
# ----> 7     for batch_in,batch_out in train_loader:
#       8         # Forward path
#       9         y_pred = resnet.forward(batch_in.view(-1,3,224,224).to(device))
#      10         loss_out = loss(y_pred,batch_out.to(device))
#
# KeyboardInterrupt:

# %% [markdown]
# 1에폭 18분 걸림
# n_worker=10기준 7분

# %%
 torch.cuda.empty_cache()

# %%
del resnet
